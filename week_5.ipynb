# %% [markdown]
# Training For Simple Movement

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from nes_py.wrappers import JoypadSpace

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor

from gym.wrappers import GrayScaleObservation, ResizeObservation

import os

def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = Monitor(env)  # log stats like episode rewards
    return env

env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)

save_path = os.path.join("train", "ppo_mario_simple")
os.makedirs(save_path, exist_ok=True)

# Create the PPO model
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log="./ppo_mario_logs/simple_move")

model.learn(total_timesteps=100000)
model.save(os.path.join(save_path, "mario_model"))

print("Training complete and model saved.")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_mario_logs/simple_move\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 207  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 2           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.060520686 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | -0.000724   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.75        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.017       |
# |    value_loss           | 31.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 3            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0067661796 |
# |    clip_fraction        | 0.234        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.301        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | 0.00661      |
# |    value_loss           | 0.785        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 4           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005899054 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -0.0554     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0629      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00123     |
# |    value_loss           | 0.258       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 5           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018590104 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.0568      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.69        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00536     |
# |    value_loss           | 18.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 6           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.022699594 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000145   |
# |    value_loss           | 27.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 7           |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015655186 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.55        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 16.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 8           |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008513823 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.061       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0883      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00374     |
# |    value_loss           | 0.686       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+04    |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 9           |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012118834 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0949      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 0.201       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.67e+04   |
# |    ep_rew_mean          | 1.09e+03   |
# | time/                   |            |
# |    fps                  | 145        |
# |    iterations           | 10         |
# |    time_elapsed         | 141        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.03805984 |
# |    clip_fraction        | 0.307      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | 0.529      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.38       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | 0.00483    |
# |    value_loss           | 12.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+04    |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 11          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010661529 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.488       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00402     |
# |    value_loss           | 1.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.67e+04     |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 151          |
# |    iterations           | 12           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0123641025 |
# |    clip_fraction        | 0.172        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | -0.016       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.152        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.00295      |
# |    value_loss           | 0.605        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.67e+04     |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 154          |
# |    iterations           | 13           |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0112268515 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.0876       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.124        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.0023       |
# |    value_loss           | 0.325        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.67e+04   |
# |    ep_rew_mean          | 1.09e+03   |
# | time/                   |            |
# |    fps                  | 156        |
# |    iterations           | 14         |
# |    time_elapsed         | 182        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02097984 |
# |    clip_fraction        | 0.144      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | 0.601      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.5        |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.00218    |
# |    value_loss           | 10.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+04    |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 15          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.011563036 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.147       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0044     |
# |    value_loss           | 0.555       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.67e+04    |
# |    ep_rew_mean          | 1.09e+03    |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 16          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010014359 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.0802      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 0.291       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.64e+04     |
# |    ep_rew_mean          | 734          |
# | time/                   |              |
# |    fps                  | 162          |
# |    iterations           | 17           |
# |    time_elapsed         | 214          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0086924415 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0996       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 0.194        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.64e+04   |
# |    ep_rew_mean          | 734        |
# | time/                   |            |
# |    fps                  | 163        |
# |    iterations           | 18         |
# |    time_elapsed         | 225        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.05110193 |
# |    clip_fraction        | 0.232      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.69      |
# |    explained_variance   | 0.553      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.12       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | 0.00225    |
# |    value_loss           | 8.05       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 734         |
# | time/                   |             |
# |    fps                  | 164         |
# |    iterations           | 19          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013628513 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.17        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.0094      |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.64e+04   |
# |    ep_rew_mean          | 734        |
# | time/                   |            |
# |    fps                  | 166        |
# |    iterations           | 20         |
# |    time_elapsed         | 246        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03673316 |
# |    clip_fraction        | 0.323      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.383      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.3       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.00253    |
# |    value_loss           | 28.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.64e+04   |
# |    ep_rew_mean          | 734        |
# | time/                   |            |
# |    fps                  | 167        |
# |    iterations           | 21         |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.01780139 |
# |    clip_fraction        | 0.222      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.9       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00659   |
# |    value_loss           | 44.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.64e+04   |
# |    ep_rew_mean          | 734        |
# | time/                   |            |
# |    fps                  | 169        |
# |    iterations           | 22         |
# |    time_elapsed         | 265        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.07431798 |
# |    clip_fraction        | 0.371      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.852      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.801      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0274    |
# |    value_loss           | 4.92       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.64e+04     |
# |    ep_rew_mean          | 734          |
# | time/                   |              |
# |    fps                  | 171          |
# |    iterations           | 23           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0041295527 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | -0.0215      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.113        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.00402      |
# |    value_loss           | 0.232        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 24          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013894612 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | 0.0182      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0636      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 0.157       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.64e+04   |
# |    ep_rew_mean          | 631        |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 25         |
# |    time_elapsed         | 293        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.01211439 |
# |    clip_fraction        | 0.0915     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.784      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.23       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -3.02e-05  |
# |    value_loss           | 5.2        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 26          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022248967 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0311      |
# |    value_loss           | 3.84        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 27          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.007827155 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.0207      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.023       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -7.73e-05   |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 28          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012502302 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.0388      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 0.0951      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 174         |
# |    iterations           | 29          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014024667 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.73        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.0187      |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 30          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.049569197 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.526       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00163     |
# |    value_loss           | 4.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 631         |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 31          |
# |    time_elapsed         | 360         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009902756 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0869      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00333    |
# |    value_loss           | 0.241       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+04    |
# |    ep_rew_mean          | 597         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 32          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013203081 |
# |    clip_fraction        | 0.0957      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0723      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.156       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.63e+04   |
# |    ep_rew_mean          | 597        |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 33         |
# |    time_elapsed         | 388        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01758936 |
# |    clip_fraction        | 0.104      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.46       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.00065   |
# |    value_loss           | 9.32       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.63e+04   |
# |    ep_rew_mean          | 597        |
# | time/                   |            |
# |    fps                  | 174        |
# |    iterations           | 34         |
# |    time_elapsed         | 399        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.10320929 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.945      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00319    |
# |    value_loss           | 3.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+04    |
# |    ep_rew_mean          | 597         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 35          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011965081 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | -0.00197    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00423    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 0.0912      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+04    |
# |    ep_rew_mean          | 597         |
# | time/                   |             |
# |    fps                  | 175         |
# |    iterations           | 36          |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010264251 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.368       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00717    |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+04    |
# |    ep_rew_mean          | 597         |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 37          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.039729632 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.569       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 2.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+04    |
# |    ep_rew_mean          | 597         |
# | time/                   |             |
# |    fps                  | 177         |
# |    iterations           | 38          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.027013352 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1           |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00947     |
# |    value_loss           | 3.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.63e+04    |
# |    ep_rew_mean          | 597         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 39          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.033876676 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | -0.182      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.518       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.0122      |
# |    value_loss           | 1.7         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.63e+04     |
# |    ep_rew_mean          | 597          |
# | time/                   |              |
# |    fps                  | 178          |
# |    iterations           | 40           |
# |    time_elapsed         | 457          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0113910325 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | -0.0269      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.192        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00159      |
# |    value_loss           | 1.08         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.63e+04   |
# |    ep_rew_mean          | 597        |
# | time/                   |            |
# |    fps                  | 179        |
# |    iterations           | 41         |
# |    time_elapsed         | 467        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.02232335 |
# |    clip_fraction        | 0.17       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.73      |
# |    explained_variance   | 0.757      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.283      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0024    |
# |    value_loss           | 3.15       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.63e+04     |
# |    ep_rew_mean          | 597          |
# | time/                   |              |
# |    fps                  | 180          |
# |    iterations           | 42           |
# |    time_elapsed         | 477          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0074025616 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.0721       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.264        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -1.52e-05    |
# |    value_loss           | 0.889        |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 1.63e+04 |
# |    ep_rew_mean          | 597      |
# | time/                   |          |
# |    fps                  | 179      |
# |    iterations           | 43       |
# |    time_elapsed         | 490      |
# |    total_timesteps      | 88064    |
# | train/                  |          |
# |    approx_kl            | 0.014114 |
# |    clip_fraction        | 0.104    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.783   |
# |    explained_variance   | 0.509    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.466    |
# |    n_updates            | 420      |
# |    policy_gradient_loss | -0.00031 |
# |    value_loss           | 0.898    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.79e+04    |
# |    ep_rew_mean          | 354         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 44          |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009196926 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.0404      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 0.725       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.79e+04   |
# |    ep_rew_mean          | 354        |
# | time/                   |            |
# |    fps                  | 179        |
# |    iterations           | 45         |
# |    time_elapsed         | 513        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.10308048 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.923     |
# |    explained_variance   | 0.0416     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.249      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00658   |
# |    value_loss           | 3.31       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.79e+04   |
# |    ep_rew_mean          | 354        |
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 46         |
# |    time_elapsed         | 522        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.06495811 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | -0.161     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0462     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0061     |
# |    value_loss           | 1.94       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.79e+04    |
# |    ep_rew_mean          | 354         |
# | time/                   |             |
# |    fps                  | 180         |
# |    iterations           | 47          |
# |    time_elapsed         | 532         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014116488 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0438      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00807     |
# |    value_loss           | 1.32        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.79e+04    |
# |    ep_rew_mean          | 354         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 48          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010119302 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | -0.00198    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0612      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0039     |
# |    value_loss           | 0.115       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.64e+04    |
# |    ep_rew_mean          | 457         |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 49          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011913935 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.977       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00977     |
# |    value_loss           | 10.4        |
# -----------------------------------------
# Training complete and model saved.

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from nes_py.wrappers import JoypadSpace
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from gym.wrappers import GrayScaleObservation, ResizeObservation
import time
def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')  # Level 1-1
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    return env
env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)
model = PPO.load("train/ppo_mario_simple/mario_model")
obs = env.reset()
done = False
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, info = env.step(action)
    env.render()
    time.sleep(0.01)
env.close()

# %% [markdown]
# Training For Complex Movement

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import COMPLEX_MOVEMENT
from nes_py.wrappers import JoypadSpace

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor

from gym.wrappers import GrayScaleObservation, ResizeObservation

import os

# Create and wrap the Mario environment
def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
    env = JoypadSpace(env, COMPLEX_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = Monitor(env)  # Logs episode reward, length, etc.
    return env

# Wrap with vector env and stack frames
env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)

# Create directory to save model
save_path = os.path.join("train", "ppo_mario_complex")
os.makedirs(save_path, exist_ok=True)

# Create the PPO model
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log="./ppo_mario_logs/complex_move")

# Train the agent
model.learn(total_timesteps=100000)

# Save the model
model.save(os.path.join(save_path, "mario_model"))

print("Training complete and model saved at:", save_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_mario_logs/complex_move\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 208  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 2          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.02756429 |
# |    clip_fraction        | 0.341      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.46      |
# |    explained_variance   | -0.000483  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.2       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | 0.003      |
# |    value_loss           | 41.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 200        |
# |    iterations           | 3          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.05004158 |
# |    clip_fraction        | 0.484      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.38      |
# |    explained_variance   | 0.365      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | 0.0359     |
# |    value_loss           | 6.36       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 4           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.035012465 |
# |    clip_fraction        | 0.463       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | -9.93e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.08        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00864     |
# |    value_loss           | 9.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 5           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.043042783 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | -0.233      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.74        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0132      |
# |    value_loss           | 13.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.02e+03   |
# |    ep_rew_mean          | 135        |
# | time/                   |            |
# |    fps                  | 157        |
# |    iterations           | 6          |
# |    time_elapsed         | 78         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.05080711 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.32      |
# |    explained_variance   | 0.785      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.832      |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.0236     |
# |    value_loss           | 4.74       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 7           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013935007 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | -0.0273     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.444       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.000174   |
# |    value_loss           | 2.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 8           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009510025 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.651       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 0.699       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 9           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023813393 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.839       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0139      |
# |    value_loss           | 8.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 10          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011676773 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.209       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.000401    |
# |    value_loss           | 0.717       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 137         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 11          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012978957 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.0591      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.377       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00802    |
# |    value_loss           | 0.685       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 12          |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.012818513 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.0606      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.141       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 0.282       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.02e+03   |
# |    ep_rew_mean          | 138        |
# | time/                   |            |
# |    fps                  | 163        |
# |    iterations           | 13         |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.03176017 |
# |    clip_fraction        | 0.437      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.09      |
# |    explained_variance   | 0.641      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.55       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.028      |
# |    value_loss           | 5.33       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 138         |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 14          |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.026661292 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.35        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00327     |
# |    value_loss           | 2.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.02e+03     |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 164          |
# |    iterations           | 15           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0071176896 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.112        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0698       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00106     |
# |    value_loss           | 0.138        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 16          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010552043 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.0395      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0711      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 17          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.019298594 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.93        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00331     |
# |    value_loss           | 17.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 169         |
# |    iterations           | 18          |
# |    time_elapsed         | 217         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010577254 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0557      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 19          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006845992 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0519      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00275    |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.72e+03    |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 20          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012348194 |
# |    clip_fraction        | 0.0706      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.00928     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0979      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00238    |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.72e+03    |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 172         |
# |    iterations           | 21          |
# |    time_elapsed         | 248         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.024497505 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.659       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 34.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.72e+03    |
# |    ep_rew_mean          | 193         |
# | time/                   |             |
# |    fps                  | 168         |
# |    iterations           | 22          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009611047 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0391      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 0.211       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.72e+03     |
# |    ep_rew_mean          | 193          |
# | time/                   |              |
# |    fps                  | 167          |
# |    iterations           | 23           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0068949824 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 0.24         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0618       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00417     |
# |    value_loss           | 0.174        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.12e+03    |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 24          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008888258 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00753    |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.12e+03    |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 25          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.048836466 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.42        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 6.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.12e+03    |
# |    ep_rew_mean          | 184         |
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 26          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.016289169 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.72       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.534       |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.0064      |
# |    value_loss           | 9.27        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.12e+03   |
# |    ep_rew_mean          | 184        |
# | time/                   |            |
# |    fps                  | 154        |
# |    iterations           | 27         |
# |    time_elapsed         | 357        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.03597021 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.69      |
# |    explained_variance   | 0.0763     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.579      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0056     |
# |    value_loss           | 1.01       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.33e+03   |
# |    ep_rew_mean          | 117        |
# | time/                   |            |
# |    fps                  | 152        |
# |    iterations           | 28         |
# |    time_elapsed         | 375        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01847229 |
# |    clip_fraction        | 0.312      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.31       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.295      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0032    |
# |    value_loss           | 1.12       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.33e+03    |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 29          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.017671451 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 6.8         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.33e+03   |
# |    ep_rew_mean          | 117        |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 30         |
# |    time_elapsed         | 412        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03082053 |
# |    clip_fraction        | 0.337      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.403      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.14       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 6.52       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.33e+03    |
# |    ep_rew_mean          | 117         |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 31          |
# |    time_elapsed         | 429         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.011383181 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.367       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 0.941       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5e+03     |
# |    ep_rew_mean          | 64.1        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 32          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017777186 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0145     |
# |    value_loss           | 3.55        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.5e+03   |
# |    ep_rew_mean          | 64.1      |
# | time/                   |           |
# |    fps                  | 145       |
# |    iterations           | 33        |
# |    time_elapsed         | 463       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.1536367 |
# |    clip_fraction        | 0.556     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.63     |
# |    explained_variance   | 0.49      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 16.1      |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 0.0336    |
# |    value_loss           | 19.2      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.5e+03    |
# |    ep_rew_mean          | 64.1       |
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 34         |
# |    time_elapsed         | 480        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.03728745 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | -0.0559    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.76       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00467   |
# |    value_loss           | 18.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.5e+03    |
# |    ep_rew_mean          | 64.1       |
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 35         |
# |    time_elapsed         | 496        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.02054061 |
# |    clip_fraction        | 0.27       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.0495     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.323      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.00617   |
# |    value_loss           | 0.909      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 36          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.022459984 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.043       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.784       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 37          |
# |    time_elapsed         | 520         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.034322325 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 5.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 38          |
# |    time_elapsed         | 530         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.054957405 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.252       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00602     |
# |    value_loss           | 3.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 59.9        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 39          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011552356 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0733      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 0.161       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28e+03    |
# |    ep_rew_mean          | 75.8        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 40          |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012817316 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | -0.149      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0371      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 0.134       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.28e+03   |
# |    ep_rew_mean          | 75.8       |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 41         |
# |    time_elapsed         | 562        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.06176882 |
# |    clip_fraction        | 0.47       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0.599      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.8        |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0197     |
# |    value_loss           | 12.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.28e+03   |
# |    ep_rew_mean          | 75.8       |
# | time/                   |            |
# |    fps                  | 149        |
# |    iterations           | 42         |
# |    time_elapsed         | 573        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.04755452 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.613      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.3        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.0158     |
# |    value_loss           | 3.66       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28e+03    |
# |    ep_rew_mean          | 75.8        |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 43          |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013716843 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 0.326       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.41e+03    |
# |    ep_rew_mean          | 89.5        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 44          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010167435 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | -0.0335     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0527      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 0.161       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.02e+03   |
# |    ep_rew_mean          | 125        |
# | time/                   |            |
# |    fps                  | 151        |
# |    iterations           | 45         |
# |    time_elapsed         | 607        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01596164 |
# |    clip_fraction        | 0.0983     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.14      |
# |    explained_variance   | 0.771      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.87       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00388    |
# |    value_loss           | 4.07       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02e+03    |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 46          |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008418869 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.33        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00173     |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.02e+03    |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 47          |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.010653399 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0929      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 0.367       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 48          |
# |    time_elapsed         | 639         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010804143 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0681      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 0.255       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14e+03    |
# |    ep_rew_mean          | 134         |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 49          |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.009601945 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.966       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00273     |
# |    value_loss           | 1.49        |
# -----------------------------------------
# Training complete and model saved at: train\ppo_mario_complex

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import COMPLEX_MOVEMENT
from nes_py.wrappers import JoypadSpace
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from gym.wrappers import GrayScaleObservation, ResizeObservation
import time
def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')  # Level 1-1
    env = JoypadSpace(env, COMPLEX_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    return env
env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)
model = PPO.load("train/ppo_mario_complex/mario_model")
obs = env.reset()
done = False
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, info = env.step(action)
    env.render()
    time.sleep(0.01)
env.close()
