# %% [markdown]
# Training For Simple Movement

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from nes_py.wrappers import JoypadSpace

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor

from gym.wrappers import GrayScaleObservation, ResizeObservation

import os

def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = Monitor(env)  # log stats like episode rewards
    return env

env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)

save_path = os.path.join("train", "ppo_mario_simple")
os.makedirs(save_path, exist_ok=True)

# Create the PPO model
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log="./ppo_mario_logs/simple_move")

model.learn(total_timesteps=100000)
model.save(os.path.join(save_path, "mario_model"))

print("Training complete and model saved.")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_mario_logs/simple_move\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 197  |
# |    iterations      | 1    |
# |    time_elapsed    | 10   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 2           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.027624924 |
# |    clip_fraction        | 0.385       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.0023      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.4         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0215      |
# |    value_loss           | 41.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 3           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010004364 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.103       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0071      |
# |    value_loss           | 0.573       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 4           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020184968 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.265       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | 0.00392     |
# |    value_loss           | 5.98        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.33e+03   |
# |    ep_rew_mean          | 702        |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 5          |
# |    time_elapsed         | 80         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01159958 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0.326      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0863     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.00122    |
# |    value_loss           | 1.1        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 128         |
# |    iterations           | 6           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.041818485 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.19        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00587     |
# |    value_loss           | 28.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 7           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015031822 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0773      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00157     |
# |    value_loss           | 0.615       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.33e+03   |
# |    ep_rew_mean          | 702        |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 8          |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01167809 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | 0.628      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0524     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00422   |
# |    value_loss           | 0.226      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.33e+03     |
# |    ep_rew_mean          | 702          |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 9            |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0071677794 |
# |    clip_fraction        | 0.158        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.216        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.141        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000915     |
# |    value_loss           | 0.614        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 10          |
# |    time_elapsed         | 177         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.030220825 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.583       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0448      |
# |    value_loss           | 7.03        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.33e+03     |
# |    ep_rew_mean          | 702          |
# | time/                   |              |
# |    fps                  | 114          |
# |    iterations           | 11           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0070748357 |
# |    clip_fraction        | 0.197        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 0.908        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.16         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | 0.00134      |
# |    value_loss           | 0.461        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 12          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007616841 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.00114     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.12        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | 0.00192     |
# |    value_loss           | 0.309       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 13          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.032510974 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.85        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.00921     |
# |    value_loss           | 3.24        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 14          |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015091084 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.374       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 1.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.33e+03    |
# |    ep_rew_mean          | 702         |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 15          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012183823 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.17        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 0.395       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 16          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008508299 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -0.0417     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0733      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 0.169       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 17          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.020276893 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.54        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00319     |
# |    value_loss           | 9.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 18          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.042457066 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.38        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00867    |
# |    value_loss           | 7.61        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | 552        |
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 19         |
# |    time_elapsed         | 304        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.02081482 |
# |    clip_fraction        | 0.177      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.74      |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.584      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.00198    |
# |    value_loss           | 0.608      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 20          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011958055 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0863      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 0.414       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 132         |
# |    iterations           | 21          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.038359124 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.578       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.00399     |
# |    value_loss           | 9.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 22          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016652482 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.14        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00569    |
# |    value_loss           | 0.421       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 552         |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 23          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009674275 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 0.309       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 564          |
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 24           |
# |    time_elapsed         | 357          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0063341907 |
# |    clip_fraction        | 0.0936       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.65        |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0687       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 0.171        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 25          |
# |    time_elapsed         | 368         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.040663257 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0.565       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.373       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00937     |
# |    value_loss           | 8.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 26          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013352642 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0383      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 27          |
# |    time_elapsed         | 389         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008126201 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0663      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 28          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012706451 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.047       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 29          |
# |    time_elapsed         | 410         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011798007 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00698     |
# |    value_loss           | 3.81        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 564          |
# | time/                   |              |
# |    fps                  | 145          |
# |    iterations           | 30           |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0049594752 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | 0.028        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.167        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.000217    |
# |    value_loss           | 0.212        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 31          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.012525117 |
# |    clip_fraction        | 0.0838      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.0042      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.138       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0037     |
# |    value_loss           | 0.212       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 32          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012063762 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | -0.0346     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0513      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00517    |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 33          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014659369 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.44        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00306     |
# |    value_loss           | 9.02        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 34          |
# |    time_elapsed         | 463         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006734635 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.0267     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.053       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0005     |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 564         |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 35          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005913958 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.00383    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.042       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00184    |
# |    value_loss           | 0.0956      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.82e+04     |
# |    ep_rew_mean          | 520          |
# | time/                   |              |
# |    fps                  | 152          |
# |    iterations           | 36           |
# |    time_elapsed         | 484          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0054393373 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 0.0284       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0303       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 0.0922       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.82e+04   |
# |    ep_rew_mean          | 520        |
# | time/                   |            |
# |    fps                  | 153        |
# |    iterations           | 37         |
# |    time_elapsed         | 495        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.06392014 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.975      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0142    |
# |    value_loss           | 9.38       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82e+04    |
# |    ep_rew_mean          | 520         |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 38          |
# |    time_elapsed         | 505         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.071174875 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.961       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.43        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0189      |
# |    value_loss           | 4.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82e+04    |
# |    ep_rew_mean          | 520         |
# | time/                   |             |
# |    fps                  | 154         |
# |    iterations           | 39          |
# |    time_elapsed         | 516         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004076327 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.0155     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0571      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00197    |
# |    value_loss           | 0.0979      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82e+04    |
# |    ep_rew_mean          | 520         |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 40          |
# |    time_elapsed         | 526         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004621053 |
# |    clip_fraction        | 0.0728      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.00154     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0305      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 0.0967      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82e+04    |
# |    ep_rew_mean          | 520         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 41          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.017671324 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.93        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00768     |
# |    value_loss           | 13.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.82e+04    |
# |    ep_rew_mean          | 520         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 42          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.003952207 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0857      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 0.223       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.82e+04     |
# |    ep_rew_mean          | 520          |
# | time/                   |              |
# |    fps                  | 157          |
# |    iterations           | 43           |
# |    time_elapsed         | 559          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0064499043 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.57        |
# |    explained_variance   | -0.00873     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.106        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 0.207        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+04    |
# |    ep_rew_mean          | 544         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 44          |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011978511 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -0.017      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0372      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 0.0946      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+04    |
# |    ep_rew_mean          | 544         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 45          |
# |    time_elapsed         | 580         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.026158636 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00583     |
# |    value_loss           | 43.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+04    |
# |    ep_rew_mean          | 544         |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 46          |
# |    time_elapsed         | 594         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.010629739 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | -0.0227     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0952      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 0.0926      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.49e+04   |
# |    ep_rew_mean          | 544        |
# | time/                   |            |
# |    fps                  | 158        |
# |    iterations           | 47         |
# |    time_elapsed         | 605        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01010774 |
# |    clip_fraction        | 0.0795     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | -0.0113    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.037      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00499   |
# |    value_loss           | 0.0928     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+04    |
# |    ep_rew_mean          | 544         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 48          |
# |    time_elapsed         | 617         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.015201933 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.496       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.019       |
# |    value_loss           | 6.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+04    |
# |    ep_rew_mean          | 544         |
# | time/                   |             |
# |    fps                  | 159         |
# |    iterations           | 49          |
# |    time_elapsed         | 628         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.016673815 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.278       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0163      |
# |    value_loss           | 2.67        |
# -----------------------------------------
# Training complete and model saved.

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from nes_py.wrappers import JoypadSpace
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from gym.wrappers import GrayScaleObservation, ResizeObservation
import time
def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')  # Level 1-1
    env = JoypadSpace(env, SIMPLE_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    return env
env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)
model = PPO.load("train/ppo_mario_simple/mario_model")
obs = env.reset()
done = False
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, info = env.step(action)
    env.render()
    time.sleep(0.01)
env.close()

# %% [markdown]
# Training For Complex Movement

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import COMPLEX_MOVEMENT
from nes_py.wrappers import JoypadSpace

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor

from gym.wrappers import GrayScaleObservation, ResizeObservation

import os

# Create and wrap the Mario environment
def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-1-1-v0')
    env = JoypadSpace(env, COMPLEX_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = Monitor(env)  # Logs episode reward, length, etc.
    return env

# Wrap with vector env and stack frames
env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)

# Create directory to save model
save_path = os.path.join("train", "ppo_mario_complex")
os.makedirs(save_path, exist_ok=True)

# Create the PPO model
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log="./ppo_mario_logs/complex_move")

# Train the agent
model.learn(total_timesteps=100000)

# Save the model
model.save(os.path.join(save_path, "mario_model"))

print("Training complete and model saved at:", save_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_mario_logs/complex_move\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 205  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 140         |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022002649 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.000728    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.00361     |
# |    value_loss           | 45.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 127         |
# |    iterations           | 3           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015647665 |
# |    clip_fraction        | 0.298       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | -0.0188     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.89        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 17.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02e+03    |
# |    ep_rew_mean          | 131         |
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 4           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014953354 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.41       |
# |    explained_variance   | 0.013       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00893    |
# |    value_loss           | 4.66        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16e+03    |
# |    ep_rew_mean          | 176         |
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 5           |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016284797 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 3.35        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.16e+03   |
# |    ep_rew_mean          | 176        |
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 6          |
# |    time_elapsed         | 103        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.17895606 |
# |    clip_fraction        | 0.579      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | 0.299      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.13       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.0877     |
# |    value_loss           | 18.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.16e+03     |
# |    ep_rew_mean          | 176          |
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 7            |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0133777745 |
# |    clip_fraction        | 0.199        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.0258       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0912       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 0.177        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+03     |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 118          |
# |    iterations           | 8            |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0106100505 |
# |    clip_fraction        | 0.17         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0324       |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 0.13         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.45e+03   |
# |    ep_rew_mean          | 164        |
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 9          |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01627092 |
# |    clip_fraction        | 0.174      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.09      |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.128      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0094    |
# |    value_loss           | 0.642      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+03    |
# |    ep_rew_mean          | 164         |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 10          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024972029 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.484       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.372       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0323      |
# |    value_loss           | 5.88        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.45e+03     |
# |    ep_rew_mean          | 164          |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 11           |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0093691265 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.18        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0316       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 0.157        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.91e+03     |
# |    ep_rew_mean          | 174          |
# | time/                   |              |
# |    fps                  | 124          |
# |    iterations           | 12           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0044645853 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.07        |
# |    explained_variance   | 0.0888       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0578       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13e+03    |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 13          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019466452 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | 0.0097      |
# |    value_loss           | 8.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13e+03    |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 125         |
# |    iterations           | 14          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016748503 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.48        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0102      |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.13e+03    |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 15          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009149354 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0513      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 0.129       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 4.13e+03 |
# |    ep_rew_mean          | 181      |
# | time/                   |          |
# |    fps                  | 123      |
# |    iterations           | 16       |
# |    time_elapsed         | 265      |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 0.008234 |
# |    clip_fraction        | 0.115    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.9     |
# |    explained_variance   | 0.0205   |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.0386   |
# |    n_updates            | 150      |
# |    policy_gradient_loss | -0.00472 |
# |    value_loss           | 0.103    |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.69e+03    |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 17          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016980644 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.107       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0402      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.69e+03    |
# |    ep_rew_mean          | 175         |
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 18          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020326164 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.21       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.719       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 11.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.69e+03   |
# |    ep_rew_mean          | 175        |
# | time/                   |            |
# |    fps                  | 128        |
# |    iterations           | 19         |
# |    time_elapsed         | 302        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00769702 |
# |    clip_fraction        | 0.0826     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.02      |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0419     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00213   |
# |    value_loss           | 0.0993     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.1e+03     |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 20          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008002048 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.0163     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0108      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.59e+03    |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 131         |
# |    iterations           | 21          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015476719 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0291      |
# |    value_loss           | 2.92        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.59e+03   |
# |    ep_rew_mean          | 156        |
# | time/                   |            |
# |    fps                  | 131        |
# |    iterations           | 22         |
# |    time_elapsed         | 343        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03376337 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.99      |
# |    explained_variance   | 0.529      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.3       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00366   |
# |    value_loss           | 31.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.59e+03    |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 23          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025338173 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | 0.071       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0197      |
# |    value_loss           | 4.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.59e+03    |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 129         |
# |    iterations           | 24          |
# |    time_elapsed         | 379         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.015887786 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | -0.355      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.83        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00614    |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.93e+03    |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 130         |
# |    iterations           | 25          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.019019814 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00584    |
# |    value_loss           | 23.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.93e+03   |
# |    ep_rew_mean          | 154        |
# | time/                   |            |
# |    fps                  | 132        |
# |    iterations           | 26         |
# |    time_elapsed         | 402        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.10043837 |
# |    clip_fraction        | 0.362      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.15      |
# |    explained_variance   | 0.709      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.7       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.00087   |
# |    value_loss           | 21.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.93e+03    |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 27          |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013741757 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | -0.184      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.902       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 2.37        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.21e+03    |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 28          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013720366 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.0455      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.6         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 14.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.21e+03    |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 29          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.025401443 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00927    |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.21e+03    |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 30          |
# |    time_elapsed         | 457         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.042475216 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.544       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 5.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.21e+03    |
# |    ep_rew_mean          | 153         |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 31          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.009515801 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0487      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 0.136       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+03    |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 32          |
# |    time_elapsed         | 480         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009837058 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.0194      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0236      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00734    |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+03    |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 33          |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.017210627 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.363       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0127      |
# |    value_loss           | 4.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+03    |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 34          |
# |    time_elapsed         | 503         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.021903742 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.133       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00893     |
# |    value_loss           | 1.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.45e+03    |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 35          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012498907 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | -0.0212     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.042       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000337   |
# |    value_loss           | 0.112       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.64e+03     |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 140          |
# |    iterations           | 36           |
# |    time_elapsed         | 526          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0074106175 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | -0.00698     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0413       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.64e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 141         |
# |    iterations           | 37          |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008964466 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.75       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.000607    |
# |    value_loss           | 15.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.64e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 142         |
# |    iterations           | 38          |
# |    time_elapsed         | 547         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.039224174 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.221       |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 0.324       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.64e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 143         |
# |    iterations           | 39          |
# |    time_elapsed         | 558         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008026906 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -0.023      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.045       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00355    |
# |    value_loss           | 0.107       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.81e+03     |
# |    ep_rew_mean          | 150          |
# | time/                   |              |
# |    fps                  | 143          |
# |    iterations           | 40           |
# |    time_elapsed         | 569          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0072641415 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00673      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0724       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00479     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.81e+03   |
# |    ep_rew_mean          | 150        |
# | time/                   |            |
# |    fps                  | 144        |
# |    iterations           | 41         |
# |    time_elapsed         | 580        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.01678068 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.968      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0107     |
# |    value_loss           | 4.25       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.81e+03    |
# |    ep_rew_mean          | 150         |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 42          |
# |    time_elapsed         | 591         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.050470047 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.662       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0143      |
# |    value_loss           | 3.73        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.81e+03   |
# |    ep_rew_mean          | 150        |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 43         |
# |    time_elapsed         | 602        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.06095542 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.782     |
# |    explained_variance   | -0.209     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.193      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.0203     |
# |    value_loss           | 2.44       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.27e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 44          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016617313 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.953       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 2.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.27e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 45          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.015635522 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00257     |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.27e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 46          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.020530347 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.78       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 16.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.27e+03   |
# |    ep_rew_mean          | 151        |
# | time/                   |            |
# |    fps                  | 150        |
# |    iterations           | 47         |
# |    time_elapsed         | 641        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01207797 |
# |    clip_fraction        | 0.129      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2         |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0562     |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00439   |
# |    value_loss           | 0.228      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.43e+03    |
# |    ep_rew_mean          | 151         |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 48          |
# |    time_elapsed         | 652         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009187441 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0959      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.000407    |
# |    value_loss           | 0.194       |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.43e+03 |
# |    ep_rew_mean          | 151      |
# | time/                   |          |
# |    fps                  | 151      |
# |    iterations           | 49       |
# |    time_elapsed         | 661      |
# |    total_timesteps      | 100352   |
# | train/                  |          |
# |    approx_kl            | 0.019288 |
# |    clip_fraction        | 0.205    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.39    |
# |    explained_variance   | 0.894    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.687    |
# |    n_updates            | 480      |
# |    policy_gradient_loss | 0.00273  |
# |    value_loss           | 5.62     |
# --------------------------------------
# Training complete and model saved at: train\ppo_mario_complex

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import COMPLEX_MOVEMENT
from nes_py.wrappers import JoypadSpace
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from gym.wrappers import GrayScaleObservation, ResizeObservation
import time
def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v0')  # Level 1-1
    env = JoypadSpace(env, COMPLEX_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    return env
env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)
model = PPO.load("train/ppo_mario_complex/mario_model")
obs = env.reset()
done = False
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, info = env.step(action)
    env.render()
    time.sleep(0.01)
env.close()

# %% [markdown]
# Different Level

# %%
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import COMPLEX_MOVEMENT
from nes_py.wrappers import JoypadSpace

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack
from stable_baselines3.common.monitor import Monitor

from gym.wrappers import GrayScaleObservation, ResizeObservation
import os

def create_env():
    env = gym_super_mario_bros.make('SuperMarioBros-2-1-v0')
    env = JoypadSpace(env, COMPLEX_MOVEMENT)
    env = ResizeObservation(env, shape=84)
    env = GrayScaleObservation(env, keep_dim=True)
    env = Monitor(env)
    return env

env = DummyVecEnv([create_env])
env = VecFrameStack(env, n_stack=4)

save_path = os.path.join("train", "ppo_mario_complex_2")
os.makedirs(save_path, exist_ok=True)

model = PPO(
    "CnnPolicy",
    env,
    verbose=1,
    tensorboard_log="./ppo_mario_logs/complex_move_2",
    learning_rate=2.5e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=4,
    ent_coef=0.01,
    clip_range=0.1
)

model.learn(total_timesteps=1_000_000)
model.save(os.path.join(save_path, "mario_model"))
print("Training complete and model saved at:", save_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# Logging to ./ppo_mario_logs/complex_move_2\PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 205  |
# |    iterations      | 1    |
# |    time_elapsed    | 9    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.01e+03     |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 216          |
# |    iterations           | 2            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0034563146 |
# |    clip_fraction        | 0.22         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.48        |
# |    explained_variance   | 0.000268     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.14         |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00824     |
# |    value_loss           | 7.95         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.46e+03     |
# |    ep_rew_mean          | 224          |
# | time/                   |              |
# |    fps                  | 194          |
# |    iterations           | 3            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0056044613 |
# |    clip_fraction        | 0.273        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.47        |
# |    explained_variance   | 0.000459     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.7         |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.000259    |
# |    value_loss           | 50.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.33e+03    |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 167         |
# |    iterations           | 4           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012559928 |
# |    clip_fraction        | 0.375       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.223       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.8        |
# |    n_updates            | 12          |
# |    policy_gradient_loss | 0.011       |
# |    value_loss           | 39.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 5           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010206129 |
# |    clip_fraction        | 0.39        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.44        |
# |    n_updates            | 16          |
# |    policy_gradient_loss | 0.0122      |
# |    value_loss           | 33.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 770         |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 6           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.019903027 |
# |    clip_fraction        | 0.506       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.0176      |
# |    value_loss           | 49.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 696         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 161         |
# |    iterations           | 7           |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.019443238 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 51.4        |
# |    n_updates            | 24          |
# |    policy_gradient_loss | 0.0161      |
# |    value_loss           | 85.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 626         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 8           |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012544417 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.7        |
# |    n_updates            | 28          |
# |    policy_gradient_loss | 0.00644     |
# |    value_loss           | 85.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 593         |
# |    ep_rew_mean          | 287         |
# | time/                   |             |
# |    fps                  | 173         |
# |    iterations           | 9           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.023821231 |
# |    clip_fraction        | 0.503       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 38.1        |
# |    n_updates            | 32          |
# |    policy_gradient_loss | 0.0186      |
# |    value_loss           | 73.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | 284         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 10          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.010624852 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.9        |
# |    n_updates            | 36          |
# |    policy_gradient_loss | 0.0136      |
# |    value_loss           | 60.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 509        |
# |    ep_rew_mean          | 283        |
# | time/                   |            |
# |    fps                  | 182        |
# |    iterations           | 11         |
# |    time_elapsed         | 123        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03250246 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.37      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 25.3       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | 0.026      |
# |    value_loss           | 44.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 473         |
# |    ep_rew_mean          | 282         |
# | time/                   |             |
# |    fps                  | 184         |
# |    iterations           | 12          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021162145 |
# |    clip_fraction        | 0.528       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.8        |
# |    n_updates            | 44          |
# |    policy_gradient_loss | 0.0262      |
# |    value_loss           | 36.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 429         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 178         |
# |    iterations           | 13          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.026784273 |
# |    clip_fraction        | 0.585       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.02        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | 0.041       |
# |    value_loss           | 46.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 402        |
# |    ep_rew_mean          | 275        |
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 14         |
# |    time_elapsed         | 162        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.31098166 |
# |    clip_fraction        | 0.691      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.962      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 15.9       |
# |    n_updates            | 52         |
# |    policy_gradient_loss | 0.0733     |
# |    value_loss           | 41.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 416        |
# |    ep_rew_mean          | 276        |
# | time/                   |            |
# |    fps                  | 180        |
# |    iterations           | 15         |
# |    time_elapsed         | 170        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.15157202 |
# |    clip_fraction        | 0.689      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 9.95       |
# |    n_updates            | 56         |
# |    policy_gradient_loss | 0.0506     |
# |    value_loss           | 19.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 429        |
# |    ep_rew_mean          | 277        |
# | time/                   |            |
# |    fps                  | 184        |
# |    iterations           | 16         |
# |    time_elapsed         | 177        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.17362708 |
# |    clip_fraction        | 0.691      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.26      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 5.72       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0641     |
# |    value_loss           | 13.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 434        |
# |    ep_rew_mean          | 279        |
# | time/                   |            |
# |    fps                  | 187        |
# |    iterations           | 17         |
# |    time_elapsed         | 185        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02217994 |
# |    clip_fraction        | 0.568      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.11      |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 10         |
# |    n_updates            | 64         |
# |    policy_gradient_loss | 0.0388     |
# |    value_loss           | 42.3       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 436       |
# |    ep_rew_mean          | 282       |
# | time/                   |           |
# |    fps                  | 191       |
# |    iterations           | 18        |
# |    time_elapsed         | 192       |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0216556 |
# |    clip_fraction        | 0.507     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | -2.18     |
# |    explained_variance   | 0.977     |
# |    learning_rate        | 0.00025   |
# |    loss                 | 13.2      |
# |    n_updates            | 68        |
# |    policy_gradient_loss | 0.0244    |
# |    value_loss           | 24.5      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 442         |
# |    ep_rew_mean          | 285         |
# | time/                   |             |
# |    fps                  | 193         |
# |    iterations           | 19          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014956338 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22          |
# |    n_updates            | 72          |
# |    policy_gradient_loss | 0.024       |
# |    value_loss           | 38.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 422         |
# |    ep_rew_mean          | 284         |
# | time/                   |             |
# |    fps                  | 196         |
# |    iterations           | 20          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016497992 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.1        |
# |    n_updates            | 76          |
# |    policy_gradient_loss | 0.0163      |
# |    value_loss           | 58          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 422        |
# |    ep_rew_mean          | 284        |
# | time/                   |            |
# |    fps                  | 198        |
# |    iterations           | 21         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02255315 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 47.9       |
# |    n_updates            | 80         |
# |    policy_gradient_loss | 0.0163     |
# |    value_loss           | 85.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 422        |
# |    ep_rew_mean          | 284        |
# | time/                   |            |
# |    fps                  | 197        |
# |    iterations           | 22         |
# |    time_elapsed         | 228        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03595524 |
# |    clip_fraction        | 0.518      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.696      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.49       |
# |    n_updates            | 84         |
# |    policy_gradient_loss | 0.0307     |
# |    value_loss           | 13.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 422         |
# |    ep_rew_mean          | 284         |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 23          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.013620786 |
# |    clip_fraction        | 0.624       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | -0.0116     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.407       |
# |    n_updates            | 88          |
# |    policy_gradient_loss | 0.0425      |
# |    value_loss           | 1.94        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 496          |
# |    ep_rew_mean          | 282          |
# | time/                   |              |
# |    fps                  | 200          |
# |    iterations           | 24           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0114382915 |
# |    clip_fraction        | 0.536        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.0411       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.254        |
# |    n_updates            | 92           |
# |    policy_gradient_loss | 0.018        |
# |    value_loss           | 0.96         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 453        |
# |    ep_rew_mean          | 287        |
# | time/                   |            |
# |    fps                  | 201        |
# |    iterations           | 25         |
# |    time_elapsed         | 253        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.02133732 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -2.03      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.36       |
# |    n_updates            | 96         |
# |    policy_gradient_loss | 0.0382     |
# |    value_loss           | 12.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 427         |
# |    ep_rew_mean          | 289         |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 26          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.011052443 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00755     |
# |    value_loss           | 35          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 429         |
# |    ep_rew_mean          | 291         |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 27          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.024763376 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.14        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | 0.0196      |
# |    value_loss           | 30.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 439         |
# |    ep_rew_mean          | 293         |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 28          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.012337158 |
# |    clip_fraction        | 0.462       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.9        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | 0.0156      |
# |    value_loss           | 44.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 439         |
# |    ep_rew_mean          | 294         |
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 29          |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.029040284 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.3        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | 0.0135      |
# |    value_loss           | 18.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 445        |
# |    ep_rew_mean          | 296        |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 30         |
# |    time_elapsed         | 294        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.01112597 |
# |    clip_fraction        | 0.453      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.95      |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 23         |
# |    n_updates            | 116        |
# |    policy_gradient_loss | 0.0174     |
# |    value_loss           | 77.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 453        |
# |    ep_rew_mean          | 297        |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 31         |
# |    time_elapsed         | 303        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02453442 |
# |    clip_fraction        | 0.459      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.98      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 3.64       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0163     |
# |    value_loss           | 31         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 441         |
# |    ep_rew_mean          | 298         |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 32          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013457891 |
# |    clip_fraction        | 0.453       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.87        |
# |    n_updates            | 124         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 18          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 447        |
# |    ep_rew_mean          | 303        |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 33         |
# |    time_elapsed         | 320        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.03079734 |
# |    clip_fraction        | 0.428      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | 0.98       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 53.5       |
# |    n_updates            | 128        |
# |    policy_gradient_loss | 0.0174     |
# |    value_loss           | 56.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 450         |
# |    ep_rew_mean          | 307         |
# | time/                   |             |
# |    fps                  | 212         |
# |    iterations           | 34          |
# |    time_elapsed         | 327         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008140047 |
# |    clip_fraction        | 0.315       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.5        |
# |    n_updates            | 132         |
# |    policy_gradient_loss | 0.009       |
# |    value_loss           | 80.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 443         |
# |    ep_rew_mean          | 309         |
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 35          |
# |    time_elapsed         | 335         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.012446882 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.88        |
# |    n_updates            | 136         |
# |    policy_gradient_loss | 0.00932     |
# |    value_loss           | 81.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 458          |
# |    ep_rew_mean          | 313          |
# | time/                   |              |
# |    fps                  | 214          |
# |    iterations           | 36           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0112115145 |
# |    clip_fraction        | 0.36         |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15           |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.0123       |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 457         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 215         |
# |    iterations           | 37          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.025144713 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.41        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 0.0167      |
# |    value_loss           | 25.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 412         |
# |    ep_rew_mean          | 314         |
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 38          |
# |    time_elapsed         | 359         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.007879749 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.9        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | 0.00694     |
# |    value_loss           | 64          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 413         |
# |    ep_rew_mean          | 315         |
# | time/                   |             |
# |    fps                  | 217         |
# |    iterations           | 39          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.034803774 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.2        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | 0.00942     |
# |    value_loss           | 79.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 423         |
# |    ep_rew_mean          | 317         |
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 40          |
# |    time_elapsed         | 381         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011901676 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.29        |
# |    n_updates            | 156         |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 49.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | 321         |
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 41          |
# |    time_elapsed         | 396         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.033396833 |
# |    clip_fraction        | 0.465       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0177      |
# |    value_loss           | 46.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 335        |
# |    ep_rew_mean          | 317        |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 42         |
# |    time_elapsed         | 410        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.04301049 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | 0.975      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 22.5       |
# |    n_updates            | 164        |
# |    policy_gradient_loss | 0.0122     |
# |    value_loss           | 58.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 350        |
# |    ep_rew_mean          | 320        |
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 43         |
# |    time_elapsed         | 422        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.05695843 |
# |    clip_fraction        | 0.585      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 6.57       |
# |    n_updates            | 168        |
# |    policy_gradient_loss | 0.0164     |
# |    value_loss           | 64.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 319         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 44          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012453785 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 9.08        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | 0.00827     |
# |    value_loss           | 48.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | 321         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 45          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.032907214 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 19.4        |
# |    n_updates            | 176         |
# |    policy_gradient_loss | 0.0184      |
# |    value_loss           | 71.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | 321         |
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 46          |
# |    time_elapsed         | 448         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014224574 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 47.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00911     |
# |    value_loss           | 81.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 344        |
# |    ep_rew_mean          | 321        |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 47         |
# |    time_elapsed         | 456        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.13116868 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | 0.984      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.64       |
# |    n_updates            | 184        |
# |    policy_gradient_loss | 0.0527     |
# |    value_loss           | 25.2       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 344        |
# |    ep_rew_mean          | 321        |
# | time/                   |            |
# |    fps                  | 211        |
# |    iterations           | 48         |
# |    time_elapsed         | 464        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.12322512 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.96      |
# |    explained_variance   | -0.126     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.606      |
# |    n_updates            | 188        |
# |    policy_gradient_loss | 0.0339     |
# |    value_loss           | 2.72       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 344        |
# |    ep_rew_mean          | 321        |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 49         |
# |    time_elapsed         | 479        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.06345696 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -1.8       |
# |    explained_variance   | -0.293     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.113      |
# |    n_updates            | 192        |
# |    policy_gradient_loss | 0.0409     |
# |    value_loss           | 1.36       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 315          |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 50           |
# |    time_elapsed         | 496          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0025807205 |
# |    clip_fraction        | 0.247        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | -0.0602      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.205        |
# |    n_updates            | 196          |
# |    policy_gradient_loss | 0.00919      |
# |    value_loss           | 0.566        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 313         |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 51          |
# |    time_elapsed         | 512         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.013633882 |
# |    clip_fraction        | 0.381       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0103      |
# |    value_loss           | 47.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 394         |
# |    ep_rew_mean          | 313         |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 52          |
# |    time_elapsed         | 524         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.016676739 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.05        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | 0.0239      |
# |    value_loss           | 26.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 386         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 53          |
# |    time_elapsed         | 537         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.014098496 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 12.2        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | 0.00841     |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 389         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 54          |
# |    time_elapsed         | 554         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.025435578 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10          |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.000734   |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 409         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 55          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.008531613 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.96        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.78        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | 303         |
# | time/                   |             |
# |    fps                  | 199         |
# |    iterations           | 56          |
# ...
# |    ep_rew_mean          | 315          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 472          |
# |    time_elapsed         | 4617         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0045198156 |
# |    clip_fraction        | 0.0819       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.846       |
# |    explained_variance   | 0.0209       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0406       |
# |    n_updates            | 1884         |
# |    policy_gradient_loss | 0.00324      |
# |    value_loss           | 0.101        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 460          |
# |    ep_rew_mean          | 318          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 473          |
# |    time_elapsed         | 4626         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0011628703 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.0646       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.039        |
# |    n_updates            | 1888         |
# |    policy_gradient_loss | 0.00202      |
# |    value_loss           | 0.096        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 477         |
# |    ep_rew_mean          | 326         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 474         |
# |    time_elapsed         | 4636        |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.013552125 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46          |
# |    n_updates            | 1892        |
# |    policy_gradient_loss | 0.0176      |
# |    value_loss           | 79.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 486         |
# |    ep_rew_mean          | 328         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 475         |
# |    time_elapsed         | 4644        |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.008037223 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.96       |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.6         |
# |    n_updates            | 1896        |
# |    policy_gradient_loss | 0.0114      |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | 328         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 476         |
# |    time_elapsed         | 4653        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.008823365 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 34.2        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0175      |
# |    value_loss           | 65.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 484         |
# |    ep_rew_mean          | 328         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 477         |
# |    time_elapsed         | 4662        |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.008184843 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.716      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.5        |
# |    n_updates            | 1904        |
# |    policy_gradient_loss | 0.00548     |
# |    value_loss           | 41          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | 328          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 478          |
# |    time_elapsed         | 4671         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0012582125 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | 0.0462       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0488       |
# |    n_updates            | 1908         |
# |    policy_gradient_loss | 0.00137      |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | 328          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 479          |
# |    time_elapsed         | 4680         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0016741632 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.806       |
# |    explained_variance   | 0.00191      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0373       |
# |    n_updates            | 1912         |
# |    policy_gradient_loss | 0.00176      |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 565          |
# |    ep_rew_mean          | 326          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 480          |
# |    time_elapsed         | 4689         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0013570272 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | -0.0105      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0341       |
# |    n_updates            | 1916         |
# |    policy_gradient_loss | 3.98e-05     |
# |    value_loss           | 0.101        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 559         |
# |    ep_rew_mean          | 329         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 481         |
# |    time_elapsed         | 4698        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.008011087 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.74        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.00503     |
# |    value_loss           | 13          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 568         |
# |    ep_rew_mean          | 331         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 482         |
# |    time_elapsed         | 4707        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.008858217 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.617      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.3        |
# |    n_updates            | 1924        |
# |    policy_gradient_loss | 0.00795     |
# |    value_loss           | 59          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 565         |
# |    ep_rew_mean          | 330         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 483         |
# |    time_elapsed         | 4716        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.012950009 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.6        |
# |    n_updates            | 1928        |
# |    policy_gradient_loss | 0.00811     |
# |    value_loss           | 50.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | 329         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 484         |
# |    time_elapsed         | 4724        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.005677113 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14.2        |
# |    n_updates            | 1932        |
# |    policy_gradient_loss | 0.00206     |
# |    value_loss           | 42.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 571         |
# |    ep_rew_mean          | 333         |
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 485         |
# |    time_elapsed         | 4733        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.005163782 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35          |
# |    n_updates            | 1936        |
# |    policy_gradient_loss | 0.00752     |
# |    value_loss           | 116         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 557        |
# |    ep_rew_mean          | 332        |
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 486        |
# |    time_elapsed         | 4742       |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.02477958 |
# |    clip_fraction        | 0.259      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | -0.932     |
# |    explained_variance   | 0.976      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 8.17       |
# |    n_updates            | 1940       |
# |    policy_gradient_loss | 0.0143     |
# |    value_loss           | 22.7       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 515          |
# |    ep_rew_mean          | 329          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 487          |
# |    time_elapsed         | 4751         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0074776234 |
# |    clip_fraction        | 0.159        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 44.5         |
# |    n_updates            | 1944         |
# |    policy_gradient_loss | 0.00799      |
# |    value_loss           | 83.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 434          |
# |    ep_rew_mean          | 330          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 488          |
# |    time_elapsed         | 4760         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0076934574 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.649       |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 16.6         |
# |    n_updates            | 1948         |
# |    policy_gradient_loss | 0.0144       |
# |    value_loss           | 77.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 427          |
# |    ep_rew_mean          | 326          |
# | time/                   |              |
# |    fps                  | 209          |
# |    iterations           | 489          |
# |    time_elapsed         | 4769         |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0049858596 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | -0.543       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 41.8         |
# |    n_updates            | 1952         |
# |    policy_gradient_loss | 0.0083       |
# |    value_loss           | 109          |
# ------------------------------------------
# Training complete and model saved at: train\ppo_mario_complex_2
